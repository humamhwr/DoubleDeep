# %%
import pandas as pd
import numpy as np
import sklearn

# %%
df = pd.read_csv("avocado.csv")

# %%
y_data = df["AveragePrice"].values

# %%
df["AveragePrice"].values
# Out:
# array([1.33, 1.35, 0.93, ..., 1.87, 1.93, 1.62])

# %%
df.head()
# Out:
#          id  diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302          1        17.99         10.38          122.80     1001.0
# 1    842517          1        20.57         17.77          132.90     1326.0
# 2  84300903          1        19.69         21.25          130.00     1203.0
# 3  84348301          1        11.42         20.38           77.58      386.1
# 4  84358402          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
np.savetxt("avocado_y.csv", y_data, delimiter=",")

# %%
df_train = df.drop(columns=["AveragePrice"])

# %%
df_train = df_train.drop(columns=["Date"])

# %%
df_train
# Out:
#        Unnamed: 0  Total Volume       4046       4225     4770  Total Bags  \
# 0               0      64236.62    1036.74   54454.85    48.16     8696.87
# 1               1      54876.98     674.28   44638.81    58.33     9505.56
# 2               2     118220.22     794.70  109149.67   130.50     8145.35
# 3               3      78992.15    1132.00   71976.41    72.58     5811.16
# 4               4      51039.60     941.48   43838.39    75.78     6183.95
# 5               5      55979.78    1184.27   48067.99    43.61     6683.91
# 6               6      83453.76    1368.92   73672.72    93.26     8318.86
# 7               7     109428.33     703.75  101815.36    80.00     6829.22
# 8               8      99811.42    1022.15   87315.57    85.34    11388.36
# 9               9      74338.76     842.40   64757.44   113.00     8625.92
# 10             10      84843.44     924.86   75595.85   117.07     8205.66
# ...

# %%
df_train['type'] = df_train['type'].map({'organic': 1, 'conventional': 0})

# %%
(np.unique(df_train["region"]))
# Out:
# array(['Albany', 'Atlanta', 'BaltimoreWashington', 'Boise', 'Boston',
#        'BuffaloRochester', 'California', 'Charlotte', 'Chicago',
#        'CincinnatiDayton', 'Columbus', 'DallasFtWorth', 'Denver',
#        'Detroit', 'GrandRapids', 'GreatLakes', 'HarrisburgScranton',
#        'HartfordSpringfield', 'Houston', 'Indianapolis', 'Jacksonville',
#        'LasVegas', 'LosAngeles', 'Louisville', 'MiamiFtLauderdale',
#        'Midsouth', 'Nashville', 'NewOrleansMobile', 'NewYork',
#        'Northeast', 'NorthernNewEngland', 'Orlando', 'Philadelphia',
#        'PhoenixTucson', 'Pittsburgh', 'Plains', 'Portland',
#        'RaleighGreensboro', 'RichmondNorfolk', 'Roanoke', 'Sacramento',
#        'SanDiego', 'SanFrancisco', 'Seattle', 'SouthCarolina',
#        'SouthCentral', 'Southeast', 'Spokane', 'StLouis', 'Syracuse',
#        'Tampa', 'TotalUS', 'West', 'WestTexNewMexico'], dtype=object)

# %%
list_of_cities = list(np.unique(df_train["region"]))
dict_of_cities = {}
for city in list_of_cities:
    dict_of_cities[city] = list_of_cities.index(city)

# %%
list_of_cities
# Out:
# ['Albany',
#  'Atlanta',
#  'BaltimoreWashington',
#  'Boise',
#  'Boston',
#  'BuffaloRochester',
#  'California',
#  'Charlotte',
#  'Chicago',
#  'CincinnatiDayton',
#  'Columbus',
#  'DallasFtWorth',
#  'Denver',
#  'Detroit',
#  'GrandRapids',
#  'GreatLakes',
#  'HarrisburgScranton',
#  'HartfordSpringfield',
#  'Houston',
#  'Indianapolis',
#  'Jacksonville',
#  'LasVegas',
#  'LosAngeles',
#  'Louisville',
#  'MiamiFtLauderdale',
#  'Midsouth',
#  'Nashville',
#  'NewOrleansMobile',
#  'NewYork',
#  'Northeast',
#  'NorthernNewEngland',
#  'Orlando',
#  'Philadelphia',
#  'PhoenixTucson',
#  'Pittsburgh',
#  'Plains',
#  'Portland',
#  'RaleighGreensboro',
#  'RichmondNorfolk',
#  'Roanoke',
#  'Sacramento',
#  'SanDiego',
#  'SanFrancisco',
#  'Seattle',
#  'SouthCarolina',
#  'SouthCentral',
#  'Southeast',
#  'Spokane',
#  'StLouis',
#  'Syracuse',
#  'Tampa',
#  'TotalUS',
#  'West',
#  'WestTexNewMexico']

# %%
dict_of_cities
# Out:
# {'Albany': 0,
#  'Atlanta': 1,
#  'BaltimoreWashington': 2,
#  'Boise': 3,
#  'Boston': 4,
#  'BuffaloRochester': 5,
#  'California': 6,
#  'Charlotte': 7,
#  'Chicago': 8,
#  'CincinnatiDayton': 9,
#  'Columbus': 10,
#  'DallasFtWorth': 11,
#  'Denver': 12,
#  'Detroit': 13,
#  'GrandRapids': 14,
#  'GreatLakes': 15,
#  'HarrisburgScranton': 16,
#  'HartfordSpringfield': 17,
#  'Houston': 18,
#  'Indianapolis': 19,
#  'Jacksonville': 20,
#  'LasVegas': 21,
#  'LosAngeles': 22,
#  'Louisville': 23,
#  'MiamiFtLauderdale': 24,
#  'Midsouth': 25,
#  'Nashville': 26,
#  'NewOrleansMobile': 27,
#  'NewYork': 28,
#  'Northeast': 29,
#  'NorthernNewEngland': 30,
#  'Orlando': 31,
#  'Philadelphia': 32,
#  'PhoenixTucson': 33,
#  'Pittsburgh': 34,
#  'Plains': 35,
#  'Portland': 36,
#  'RaleighGreensboro': 37,
#  'RichmondNorfolk': 38,
#  'Roanoke': 39,
#  'Sacramento': 40,
#  'SanDiego': 41,
#  'SanFrancisco': 42,
#  'Seattle': 43,
#  'SouthCarolina': 44,
#  'SouthCentral': 45,
# ...

# %%
df_train['type'] = df_train['type'].map({'organic': 1, 'conventional': 0})
df_train['region'] = df_train['region'].map(dict_of_cities)

# %%
np.savetxt("avocado_x_processed.csv", df_processed, delimiter=",")

# %%
df_processed
# Out:
# array([[0.00000000e+00, 7.54604158e-01, 1.21788524e-02, ...,
#         0.00000000e+00, 2.36707252e-02, 0.00000000e+00],
#        [1.38842006e-05, 7.61923001e-01, 9.36183881e-03, ...,
#         0.00000000e+00, 2.79766643e-02, 0.00000000e+00],
#        [1.23974159e-05, 7.32812617e-01, 4.92611321e-03, ...,
#         0.00000000e+00, 1.24903965e-02, 0.00000000e+00],
#        ...,
#        [4.63355907e-04, 7.08767729e-01, 6.13647970e-02, ...,
#         5.14839897e-05, 1.03894691e-01, 2.72865145e-03],
#        [4.39373568e-04, 7.12014533e-01, 6.71200243e-02, ...,
#         4.39373568e-05, 8.86655859e-02, 2.32867991e-03],
#        [4.44649337e-04, 7.06975469e-01, 1.17014324e-01, ...,
#         4.04226670e-05, 8.15729421e-02, 2.14240135e-03]])

# %%
df_train.to_csv("avocado_x.csv")

# %%
from sklearn.preprocessing import normalize
from sklearn import preprocessing
max_abs_scaler = preprocessing.MaxAbsScaler()
df_processed = max_abs_scaler.fit_transform(df_train.values)
df_processed = normalize(df_train.values)

# %%
df = pd.read_csv("breast_cancer.csv")

# %%
df['diagnosis'] = df['diagnosis'].map({'M': 1, 'B': 0})

# %%
y_data = df["diagnosis"].values

# %%
df_train = df.drop(columns=["id", "diagnosis", "Unnamed: 32"])
df_train = df_train.dropna()

# %%
df_train.shape
# Out:
# (569, 30)

# %%
df_train.shape
# Out:
# (569, 30)

# %%
np.savetxt("cancer_y.csv", y_data, delimiter=",")

# %%
from sklearn.preprocessing import normalize
from sklearn import preprocessing
max_abs_scaler = preprocessing.MaxAbsScaler()
df_processed = max_abs_scaler.fit_transform(df_train.values)

# %%
np.savetxt("breast_cancer_x.csv", df_train.values, delimiter=",")

# %%
df = pd.read_csv("datasets/cryo/cryo.csv", delimiter=",")
# df['Dataset'] = df['Dataset'].map({2: 1, 1: 0})
# df['Gender'] = df['Gender'].map({"Female": 1, "Male": 0})
# df = df.drop(columns=["hospital_number"])
df = df.dropna()

# %%
y_data = df["Result_of_Treatment"].values
np.savetxt("cryo_y.csv", y_data, delimiter=",")

# %%
df_train = df.drop(columns=["Result_of_Treatment"])
# df_train = df_train.dropna()
df_processed = max_abs_scaler.fit_transform(df_train.values)
df.shape
# Out:
# (90, 7)

# %%
np.savetxt("cryo_x.csv", df_processed, delimiter=",")
